# %%
import numpy as np
import pandas as pd

# %%
datawith = pd.read_csv('with.csv')
datawith.loc[datawith['Married']=="Yes",'Married']=1
datawith.loc[datawith['Married']=='No','Married']=0
datawith.loc[datawith['Education']=="Graduate",'Education']=1
datawith.loc[datawith['Education']=='Not Graduate','Education']=0
datawith.loc[datawith['Self_Employed']=="Yes",'Self_Employed']=1
datawith.loc[datawith['Self_Employed']=='No','Self_Employed']=0
datawith.loc[datawith['Property_Area']=="Urban",'Property_Area']=0
datawith.loc[datawith['Property_Area']=='Semiurban','Property_Area']=1
datawith.loc[datawith['Property_Area']=='Rural', 'Property_Area']=2
datawith.head()
# Out:
#    Unnamed: 0  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0           0        0           0          1              0             5849
# 1           1        1           1          1              0             4583
# 2           2        1           0          1              1             3000
# 3           3        1           0          0              0             2583
# 4           4        0           0          1              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0  146.412162             360.0             1.0
# 1             1508.0  128.000000             360.0             1.0
# 2                0.0   66.000000             360.0             1.0
# 3             2358.0  120.000000             360.0             1.0
# 4                0.0  141.000000             360.0             1.0
#
#    Property_Area  Loan_Status
# 0              0            1
# 1              2            0
# 2              0            1
# 3              0            1
# 4              0            1

# %%
datawo = pd.read_csv('without.csv')
datawo.loc[datawo['Married']=="Yes",'Married']=1
datawo.loc[datawo['Married']=='No','Married']=0
datawo.loc[datawo['Education']=="Graduate",'Education']=1
datawo.loc[datawo['Education']=='Not Graduate','Education']=0
datawo.loc[datawo['Self_Employed']=="Yes",'Self_Employed']=1
datawo.loc[datawo['Self_Employed']=='No','Self_Employed']=0
datawo.loc[datawo['Property_Area']=="Urban",'Property_Area']=0
datawo.loc[datawo['Property_Area']=='Semiurban','Property_Area']=1
datawo.loc[datawo['Property_Area']=='Rural', 'Property_Area']=2
datawo.head()
# Out:
#    Unnamed: 0  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         333        1           0          1              0            63337
# 1         171        1           3          1              0            51763
# 2         155        1           3          1              0            39999
# 3         185        1           0          1              1            39147
# 4         443        0           1          1              0            37719
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       490.0               180               1
# 1                0.0       700.0               300               1
# 2                0.0       600.0               180               0
# 3             4750.0       120.0               360               1
# 4                0.0       152.0               360               1
#
#    Property_Area  Loan_Status
# 0              0            1
# 1              0            1
# 2              1            1
# 3              1            1
# 4              1            1

# %%
X1 = datawith.drop("Loan_Status", axis=1)
y1 = datawith["Loan_Status"]
print(X1.shape, y1.shape)
# Out:
# (614, 11) (614,)

# %%
X2 = datawo.drop("Loan_Status", axis=1)
y2 = datawo["Loan_Status"]
print(X2.shape, y2.shape)
# Out:
# (599, 11) (599,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from keras.utils import to_categorical

X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, random_state=1, stratify=y1)
X1_scaler = StandardScaler().fit(X1_train)
X1_train_scaled = X1_scaler.transform(X1_train)
X1_test_scaled = X1_scaler.transform(X1_test)


# Step 1: Label-encode data set
label1_encoder = LabelEncoder()
label1_encoder.fit(y1_train)
encoded_y1_train = label1_encoder.transform(y1_train)
encoded_y1_test = label1_encoder.transform(y1_test)

# Step 2: Convert encoded labels to one-hot-encoding
y1_train_categorical = to_categorical(encoded_y1_train)
y1_test_categorical = to_categorical(encoded_y1_test)
# Out:
# Using TensorFlow backend.

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, random_state=1, stratify=y2)
X2_scaler = StandardScaler().fit(X2_train)
X2_train_scaled = X2_scaler.transform(X2_train)
X2_test_scaled = X2_scaler.transform(X2_test)


# Step 1: Label-encode data set
label2_encoder = LabelEncoder()
label2_encoder.fit(y2_train)
encoded_y2_train = label2_encoder.transform(y2_train)
encoded_y2_test = label2_encoder.transform(y2_test)

# Step 2: Convert encoded labels to one-hot-encoding
y2_train_categorical = to_categorical(encoded_y2_train)
y2_test_categorical = to_categorical(encoded_y2_test)

# %%
from keras.models import Sequential
from keras.layers import Dense

model1 = Sequential()
model1.add(Dense(units=100, activation='relu', input_dim=11))
model1.add(Dense(units=100, activation='relu'))
model1.add(Dense(units=2, activation='softmax'))

model2 = Sequential()
model2.add(Dense(units=100, activation='relu', input_dim=11))
model2.add(Dense(units=100, activation='relu'))
model2.add(Dense(units=2, activation='softmax'))

# %%
model1.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])
model1.fit(
    X1_train_scaled,
    y1_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
#  - 0s - loss: 0.6311 - acc: 0.6935
# Epoch 2/100
#  - 0s - loss: 0.5191 - acc: 0.8109
# Epoch 3/100
#  - 0s - loss: 0.4631 - acc: 0.8261
# Epoch 4/100
#  - 0s - loss: 0.4339 - acc: 0.8261
# Epoch 5/100
#  - 0s - loss: 0.4202 - acc: 0.8261
# Epoch 6/100
#  - 0s - loss: 0.4067 - acc: 0.8326
# Epoch 7/100
#  - 0s - loss: 0.3989 - acc: 0.8326
# Epoch 8/100
#  - 0s - loss: 0.3891 - acc: 0.8391
# Epoch 9/100
#  - 0s - loss: 0.3797 - acc: 0.8391
# Epoch 10/100
#  - 0s - loss: 0.3711 - acc: 0.8435
# Epoch 11/100
#  - 0s - loss: 0.3659 - acc: 0.8457
# Epoch 12/100
#  - 0s - loss: 0.3532 - acc: 0.8609
# Epoch 13/100
#  - 0s - loss: 0.3453 - acc: 0.8587
# Epoch 14/100
#  - 0s - loss: 0.3401 - acc: 0.8543
# Epoch 15/100
#  - 0s - loss: 0.3340 - acc: 0.8587
# Epoch 16/100
#  - 0s - loss: 0.3242 - acc: 0.8630
# Epoch 17/100
#  - 0s - loss: 0.3146 - acc: 0.8652
# Epoch 18/100
#  - 0s - loss: 0.3096 - acc: 0.8696
# Epoch 19/100
#  - 0s - loss: 0.3038 - acc: 0.8674
# Epoch 20/100
#  - 0s - loss: 0.2981 - acc: 0.8739
# Epoch 21/100
#  - 0s - loss: 0.2920 - acc: 0.8783
# Epoch 22/100
#  - 0s - loss: 0.2844 - acc: 0.8783
# Epoch 23/100
#  - 0s - loss: 0.2791 - acc: 0.8913
# Epoch 24/100
#  - 0s - loss: 0.2765 - acc: 0.8848
# Epoch 25/100
#  - 0s - loss: 0.2670 - acc: 0.8978
# Epoch 26/100
#  - 0s - loss: 0.2632 - acc: 0.8935
# Epoch 27/100
#  - 0s - loss: 0.2527 - acc: 0.8891
# Epoch 28/100
#  - 0s - loss: 0.2494 - acc: 0.9065
# Epoch 29/100
#  - 0s - loss: 0.2461 - acc: 0.8957
# Epoch 30/100
#  - 0s - loss: 0.2391 - acc: 0.9022
# Epoch 31/100
#  - 0s - loss: 0.2446 - acc: 0.8978
# Epoch 32/100
#  - 0s - loss: 0.2336 - acc: 0.9043
# Epoch 33/100
#  - 0s - loss: 0.1553 - acc: 0.9465
# Epoch 67/100
#  - 0s - loss: 0.1509 - acc: 0.9532
# Epoch 68/100
#  - 0s - loss: 0.1468 - acc: 0.9488
# Epoch 69/100
#  - 0s - loss: 0.1427 - acc: 0.9532
# Epoch 70/100
#  - 0s - loss: 0.1538 - acc: 0.9510
# Epoch 71/100
#  - 0s - loss: 0.1445 - acc: 0.9488
# Epoch 72/100
#  - 0s - loss: 0.1381 - acc: 0.9532
# Epoch 73/100
#  - 0s - loss: 0.1348 - acc: 0.9532
# Epoch 74/100
#  - 0s - loss: 0.1332 - acc: 0.9532
# Epoch 75/100
#  - 0s - loss: 0.1318 - acc: 0.9555
# Epoch 76/100
#  - 0s - loss: 0.1261 - acc: 0.9577
# Epoch 77/100
#  - 0s - loss: 0.1539 - acc: 0.9421
# Epoch 78/100
#  - 0s - loss: 0.1445 - acc: 0.9399
# Epoch 79/100
#  - 0s - loss: 0.1399 - acc: 0.9376
# Epoch 80/100
#  - 0s - loss: 0.1686 - acc: 0.9354
# Epoch 81/100
#  - 0s - loss: 0.1458 - acc: 0.9399
# Epoch 82/100
#  - 0s - loss: 0.1277 - acc: 0.9555
# Epoch 83/100
#  - 0s - loss: 0.1203 - acc: 0.9599
# Epoch 84/100
#  - 0s - loss: 0.1195 - acc: 0.9688
# Epoch 85/100
#  - 0s - loss: 0.1150 - acc: 0.9621
# Epoch 86/100
#  - 0s - loss: 0.1131 - acc: 0.9599
# Epoch 87/100
#  - 0s - loss: 0.1104 - acc: 0.9710
# Epoch 88/100
#  - 0s - loss: 0.1679 - acc: 0.9332
# Epoch 89/100
#  - 0s - loss: 0.1464 - acc: 0.9532
# Epoch 90/100
#  - 0s - loss: 0.1152 - acc: 0.9599
# Epoch 91/100
#  - 0s - loss: 0.1081 - acc: 0.9599
# Epoch 92/100
#  - 0s - loss: 0.1043 - acc: 0.9710
# Epoch 93/100
#  - 0s - loss: 0.1096 - acc: 0.9555
# Epoch 94/100
#  - 0s - loss: 0.1212 - acc: 0.9465
# Epoch 95/100
#  - 0s - loss: 0.1083 - acc: 0.9577
# Epoch 96/100
#  - 0s - loss: 0.1018 - acc: 0.9599
# Epoch 97/100
#  - 0s - loss: 0.0977 - acc: 0.9755
# Epoch 98/100
#  - 0s - loss: 0.0961 - acc: 0.9688
# Epoch 99/100
#  - 0s - loss: 0.0945 - acc: 0.9755
# Epoch 100/100
#  - 0s - loss: 0.0912 - acc: 0.9710

# %%
model1_loss, model1_accuracy = model1.evaluate(X1_test_scaled, y1_test_categorical, verbose=2)
print(f"Normal Neural Network with data - Loss: {model1_loss}, Accuracy: {model1_accuracy}")

model2_loss, model2_accuracy = model2.evaluate(X2_test_scaled, y2_test_categorical, verbose=2)
print(f"Normal Neural Network with/out data - Loss: {model2_loss}, Accuracy: {model2_accuracy}")
# Out:
# Normal Neural Network with data - Loss: 0.8644619189299546, Accuracy: 0.8181818158595593
# Normal Neural Network with/out data - Loss: 0.6731449913978577, Accuracy: 0.7666666634877523

# %%
model1.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 100)               1200
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 11,502
# Trainable params: 11,502
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 100)               1200
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 11,502
# Trainable params: 11,502
# Non-trainable params: 0
# _________________________________________________________________
